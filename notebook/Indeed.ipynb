# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
xdf = pd.read_csv("/srv/sync/cpj/IND/data/train/train_features.csv")
ydf = pd.read_csv("/srv/sync/cpj/IND/data/train/train_salaries.csv")

# %%
xdf
# Out:
#                    jobId companyId         jobType       degree      major  \
# 0       JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1       JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2       JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3       JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4       JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
# ...                  ...       ...             ...          ...        ...
# 999995  JOB1362685407682    COMP56  VICE_PRESIDENT    BACHELORS  CHEMISTRY
# 999996  JOB1362685407683    COMP24             CTO  HIGH_SCHOOL       NONE
# 999997  JOB1362685407684    COMP23          JUNIOR  HIGH_SCHOOL       NONE
# 999998  JOB1362685407685     COMP3             CFO      MASTERS       NONE
# 999999  JOB1362685407686    COMP59          JUNIOR    BACHELORS       NONE
#
#          industry  yearsExperience  milesFromMetropolis
# 0          HEALTH               10                   83
# 1             WEB                3                   73
# 2          HEALTH               10                   38
# 3            AUTO                8                   17
# 4         FINANCE                8                   16
# ...           ...              ...                  ...
# 999995     HEALTH               19                   94
# 999996    FINANCE               12                   35
# 999997  EDUCATION               16                   81
# 999998     HEALTH                6                    5
# 999999  EDUCATION               20                   11
#
# [1000000 rows x 8 columns]

# %%
ydf
# Out:
#                    jobId  salary
# 0       JOB1362684407687     130
# 1       JOB1362684407688     101
# 2       JOB1362684407689     137
# 3       JOB1362684407690     142
# 4       JOB1362684407691     163
# ...                  ...     ...
# 999995  JOB1362685407682      88
# 999996  JOB1362685407683     160
# 999997  JOB1362685407684      64
# 999998  JOB1362685407685     149
# 999999  JOB1362685407686      88
#
# [1000000 rows x 2 columns]

# %%
ydf['salary'].describe()
# Out:
# count    1000000.000000
# mean         116.061818
# std           38.717936
# min            0.000000
# 25%           88.000000
# 50%          114.000000
# 75%          141.000000
# max          301.000000
# Name: salary, dtype: float64

# %%
import seaborn as sns
sns.distplot(ydf['salary'])
# Out:
# /home/jcadic/anaconda3/envs/py36/lib/python3.6/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
#skewness and kurtosis
print("Skewness: %f" % ydf['salary'].skew())
print("Kurtosis: %f" % ydf['salary'].kurt())
# Out:
# Skewness: 0.346415
# Kurtosis: -0.025579

# %%
data
# Out:
#         salary companyId
# 0          130    COMP37
# 1          101    COMP19
# 2          137    COMP52
# 3          142    COMP38
# 4          163     COMP7
# ...        ...       ...
# 999995      88    COMP56
# 999996     160    COMP24
# 999997      64    COMP23
# 999998     149     COMP3
# 999999      88    COMP59
#
# [1000000 rows x 2 columns]

# %%
for c in xdf.columns:
    print("=======")
    print(xdf[c].describe())
# Out:
# =======
# count              1000000
# unique             1000000
# top       JOB1362684910230
# freq                     1
# Name: jobId, dtype: object
# =======
# count     1000000
# unique         63
# top        COMP39
# freq        16193
# Name: companyId, dtype: object
# =======
# count     1000000
# unique          8
# top        SENIOR
# freq       125886
# Name: jobType, dtype: object
# =======
# count         1000000
# unique              5
# top       HIGH_SCHOOL
# freq           236976
# Name: degree, dtype: object
# =======
# count     1000000
# unique          9
# top          NONE
# freq       532355
# Name: major, dtype: object
# =======
# count     1000000
# unique          7
# top           WEB
# freq       143206
# Name: industry, dtype: object
# =======
# count    1000000.000000
# mean          11.992386
# std            7.212391
# min            0.000000
# 25%            6.000000
# 50%           12.000000
# 75%           18.000000
# max           24.000000
# Name: yearsExperience, dtype: float64
# =======
# count    1000000.000000
# mean          49.529260
# std           28.877733
# min            0.000000
# 25%           25.000000
# 50%           50.000000
# 75%           75.000000
# max           99.000000
# Name: milesFromMetropolis, dtype: float64

# %%
def cat_view(var):
    data = pd.concat([ydf['salary'], xdf[var]], axis=1)
    f, ax = plt.subplots(figsize=(8, 6))
    fig = sns.boxplot(x=var, y="salary", data=data)

# %%
cat_view('jobType')

# %%
cat_view('companyId')

# %%
cat_view('companyId')

# %%
cat_view('major')

# %%
cat_view('yearsExperience')

# %%
cat_view('milesFromMetropolis')
